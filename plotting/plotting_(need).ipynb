# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need)</span></div>

# %% [markdown]
# ## 1 A simple plot

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# ### 1.1 Let’s look at some code.

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.plot(x, y_1, color='red', linestyle='dashed', label='Y values')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')
plt.show()

# %%
plt.plot(x, y_2, color='red', linestyle='dashed', linewidth=2)
plt.show()
plt.plot(x, y_2, c='red', ls='dashed', lw=2)
plt.show()

# ^ Produce the same graph
# you can use c --> color, ls --> linestyle, le --> linewidth

# Don't forget to type plt.show() to produce the graph

# %%
# the default settings for plotting graphs

plt.plot(x, y_1)
plt.show()

# %% [markdown]
# ### 1.2 Adding another plot

# %%
plt.plot(x, y_1, color='red', linestyle='dashed', label='Y values')
plt.plot(x, y_2, color='blue', label='Y2 values')     # Second plot
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')
plt.show()

# You can plot 2 sets of data on the same graph by adding another plt.plot() line below the previous before the plt.show()
# command.

# %% [markdown]
# ### 1.3 Yet another plot but with error bars

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = .1, 0.75

# Lets start plotting
plt.plot(x, y_1, color='red', linestyle='dashed', label='Y values')
plt.plot(x, y_2, color='blue', label='Y2 values')
plt.errorbar(x, y_3, xerr=x_error, yerr=y_error, color='green', label='Y3 with errors')    # Third plot w/ error bars
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')
plt.show()

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error = [0.3, 0.12, 0.05, 0.05, 0.2, 0.7, 0.1]
y_error = [0.6, 0.7, 0.08, 0.3, 1.4, 0.05, 1.0]

# Specifying the x and y errors rather than a fixed value

# Lets start plotting
plt.plot(x, y_1, color='red', linestyle='dashed', label='Y values')
plt.plot(x, y_2, color='blue', label='Y2 values')
plt.errorbar(x, y_3, xerr=x_error, yerr=y_error, color='green', label='Y3 with errors')    # Third plot w/ error bars
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### 1.4 Experiment, Experiment, Experiment

# %%
# alpha changes the opacity of the gridlines

# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error = [0.3, 0.12, 0.05, 0.05, 0.2, 0.7, 0.1]
y_error = [0.6, 0.7, 0.08, 0.3, 1.4, 0.05, 1.0]

# Specifying the x and y errors rather than a fixed value

# Lets start plotting
plt.plot(x, y_1, color='#fb6a4a', linestyle='dashed', label='Y values')
plt.plot(x, y_2, color='#65e6d9', label='Y2 values')
plt.errorbar(x, y_3, xerr=x_error, yerr=y_error, color='#e66583', label='Y3 with errors')    # Third plot w/ error bars
plt.xlabel('x-values', fontsize=100)
plt.ylabel('y-values', fontsize=5)
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### 1.5 Better with NumPy

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

np_x = np.array(x)
np_y_1 = np.array(y_1)
np_y_2 = np.array(y_2)

plt.plot(np_x, np_y_1, color='red', linestyle='dashed', label='Y values')
plt.plot(np_x, np_y_2, color='blue', label='Y2 values')
plt.show()

# %% [markdown]
# ### 1.6 Adding mathematical functions

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, color='red', linestyle='dashed', label='x^2')
plt.plot(x, sin_x, color='blue', label='sin(x)')
plt.legend()
plt.show()

# %% [markdown]
# ### 1.7 We need another axis!

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, color='red', linestyle='dashed', label='x^2')
plt.legend(loc='best')

# This creates a new y-axis for the plot that comes after
plt.twinx()
plt.plot(x, sin_x, color='blue', label='sin(x)')
plt.legend(loc='right')

plt.show()

# %%
x = np.linspace(0, 6, 100)    # plots 100 points from x=0 to x=6
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, color='red', linestyle='dashed', label='x^2')
plt.legend(loc='best')

# This creates a new y-axis for the plot that comes after
plt.twinx()
plt.plot(x, sin_x, color='blue', label='sin(x)')
plt.legend(loc='right')

plt.show()

# %% [markdown]
# ### 1.8 Saving to disc

# %%
x = np.linspace(0, 6, 100)
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, color='red', linestyle='dashed', label='x^2')
plt.legend(loc='lower left')

# This creates a new y-axis for the plot that comes after
plt.twinx()
plt.plot(x, sin_x, color='blue', label='sin(x)')
plt.legend(loc='lower right')

# plt.savefig('simple-plot.png', dpi=150)

# ^ saves the plot as the specified file type stated in the extension portion of the file name. dpi stands for
# dots-per-inch
# file will be saved to the same directory as the current notebook on your computer

# %%
# to change the directory in which the plot is saved on a Windows machine, you can change the file name to include the
# directory:

# plt.savefig('C://Desktop/simple-plot.png', dpi=150)

# change the file type by changing the extension in the file name. increase the dpi for a higher resolution image

# %% [markdown]
# ## 2 A real example: Global Warming

# %% [markdown]
# ### 2.1 Plotting data from files

# %%
data = np.loadtxt('Complete_TAVG_daily.txt', skiprows=24)
date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.ylim([-8, 8])
plt.show()

# plot is different from that in the website but apparently that's normal

# %%
plt.plot(date, anomaly, alpha=.5)
plt.ylim([-8, 8])
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')
plt.show()

# adding a horizontal line at y=0

# %%
plt.style.use('fivethirtyeight')

data = np.loadtxt('Complete_TAVG_daily.txt', skiprows=24)

date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')
plt.ylim([-8, 8])

plt.xlabel('Date')
plt.ylabel('Temperature Anomaly')
plt.title('Temperature anomaly\n(Relative to  average from Jan 1951 - Dec 1980.)')
plt.show()

# using one of the default template graph styles

# %%
plt.style.use('fivethirtyeight')

data = np.loadtxt('Complete_TAVG_daily.txt', skiprows=24)

date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')
plt.ylim([-8, 8])

plt.xlabel('Date')
plt.style.use('default')      # used to jump out of the graph style template to use the default style
plt.ylabel('Temperature Anomaly')
plt.title('Temperature anomaly\n(Relative to  average from Jan 1951 - Dec 1980.)')
plt.show()

# %% [markdown]
# ### 2.2 xkcd!

# %%
plt.xkcd()    # use this command at the top to plot the graph in a wonky xkcd style

data = np.loadtxt('Complete_TAVG_daily.txt', skiprows=24)

date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')
plt.ylim([-8, 8])

plt.xlabel('Date')
plt.ylabel('Temperature Anomaly')
plt.title('Temperature anomaly\n(Relative to  average from Jan 1951 - Dec 1980.)')
plt.show()

# %% [markdown]
# ## Exercise 1 :  Fill in the blanks

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5]
y = [0, 4, 8, 12, 16, 20]
y_err = [0.0, 0.5, 1.0, 1.5, 2.0, 2.5]
x_err = .25

plt.style.use('default')

plt.errorbar(x, y, xerr=x_err, yerr=y_err,
             color='#821f14', linestyle='--',
             marker='o', markerfacecolor='yellow',
             ecolor='black',capsize=5,
             label='Y values with errors')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='lower right')
# save_file_figure(plt, argv)                  # Hide
plt.show(block=False)

# %% [markdown]
# ## Exercise 2 :  A simple mathematical plot

# %%
x = np.array(np.linspace(0, 50, 1000))
y = np.e**(-x/10)*np.sin(x)

plt.plot(x, y)
plt.xlabel('x', fontsize=15, color='darkblue')
plt.ylabel('y', rotation =0, fontsize=15, color='darkblue')
plt.grid(alpha=0.25)
plt.ylim(-1, 1)
plt.title(r'$y = e^{-x/10}sin(x)$', fontsize=20)
plt.show()
